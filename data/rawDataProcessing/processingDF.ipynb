# %%
import pandas as pd

combined_df2 = pd.read_csv('combined/99-23NBA_per_100_poss.csv')

# %%
#filtering out to only bench players 
bench_players2 = combined_df2[combined_df2["GS"] <41 ]
bench_players3 = combined_df2[combined_df2["GS"] <41 ]
#dictionary for top teams, average teams, and bottom teams
team_performance = {
    "1999-2000": {
        "top": ["LAL", "POR","IND", "UTH"],
        "bottom": ["CHI","VAN" , "GSW", "LAC"]
    },
    "2000-2001": {
        "top": ["LAL", "PHI","SAC", "SAS"],
        "bottom": ["CHI","VAN" , "GSW", "WAS"]
    },
    "2001-2002": {
        "top": ["SAC", "LAL","DAL", "SAS"],
        "bottom": ["CHI","DEN" , "GSW", "MEM"]
    },
    "2002-2003": {
        "top": ["MIN", "SAC","DAL", "SAS"],
        "bottom": ["MIA","TOR" , "CLE", "DEN"]
    },
    "2003-2004": {
        "top": ["IND", "MIN","LAL", "SAS"],
        "bottom": ["ORL","CHI" , "WAS", "LAC"]
    },
    "2004-2005": {
        "top": ["MIA", "PHO","SAS", "DAL"],
        "bottom": ["CHA","ATL" , "UTH", "NOH"]
    },
    "2005-2006": {
        "top": ["DET", "SAS", "DAL", "PHO"],
        "bottom": ["POR","NYK" , "CHA", "ATL"]
    },
    "2006-2007": {
        "top": ["DAL", "PHO","SAS", "DET"],
        "bottom": ["MEM","BOS" , "MIL", "ATL"]
    },
    "2007-2008": {
        "top": ["BOS", "DET","LAL", "NOH"],
        "bottom": ["MEM","MIA" , "SEA", "MIN"]
    },
    "2008-2009": {
        "top": ["CLE", "LAL","BOS", "ORL"],
        "bottom": ["SAC","WAS" , "LAC", "OKC"]
    },
    "2009-2010": {
        "top": ["CLE", "ORL","LAL", "DAL"],
        "bottom": ["NJN","MIN", "SAC", "WAS"]
    },
    "2010-2011": {
        "top": ["CHI", "SAS","MIA", "DAL"],
        "bottom": ["MIN","CLE" , "TOR", "WAS"]
    },
    "2011-2012": {
        "top": ["CHI", "SAS", "OKC", "MIA"],
        "bottom": ["CHA", "WAS", "NOH", "CLE"]
    },
    "2012-2013": {
        "top": ["MIA", "OKC", "SAS", "DEN"],
        "bottom": ["CHA", "ORL", "CLE", "PHO"]
    },
    "2013-2014": {
        "top": ["SAS", "LAC", "OKC", "IND"],
        "bottom": ["MIL", "PHI", "ORL", "UTH"]
    },
    "2014-2015": {
        "top": ["GSW", "ATL", "HOU", "LAC"],
        "bottom": ["MIN", "NYK", "PHI", "LAL"]
    },
    "2015-2016": {
        "top": ["GSW", "SAS", "CLE", "TOR"],
        "bottom": ["PHI", "LAL", "BRK", "PHO"]
    },
    "2016-2017": {
        "top": ["GSW", "SAS", "HOU", "BOS"],
        "bottom": ["BRK", "PHO", "LAL", "PHI"]
    },
    "2017-2018": {
        "top": ["HOU", "TOR", "GSW", "BOS"],
        "bottom": ["PHO", "MEM", "DAL", "ATL"]
    },
    "2018-2019": {
        "top": ["MIL", "TOR", "GSW", "DEN"],
        "bottom": ["NYK", "PHO", "CLE", "CHI"]
    },
    "2019-2020": {
        "top": ["MIL", "TOR", "LAL", "LAC"],
        "bottom": ["GSW", "MIN", "CLE", "DET"]
    },
    "2020-2021": {
        "top": ["UTH", "PHO", "PHI", "BRK"],
        "bottom": ["HOU", "DET", "ORL", "OKC"]
    },
    "2021-2022": {
        "top": ["PHO", "MEM", "GSW", "MIA"],
        "bottom": ["HOU", "ORL", "DET", "OKC"]
    },
    "2022-2023": {
        "top": ["MIL", "BOS", "PHI", "DEN"],
        "bottom": ["DET", "SAS", "HOU", "CHA"]
    }
}

team_performance2 = {
    "1999-2000": {
        "top": ["LAL", "POR","IND", "UTH", "PHO", "SAS"],
        "bottom": ["CHI","VAN" , "GSW", "LAC", "ATL", "WAS"]
    },
    "2000-2001": {
        "top": ["LAL", "PHI","SAC", "SAS", "DAL", "UTH"],
        "bottom": ["CHI","VAN" , "GSW", "WAS", "ATL", "NJN"]
    },
    "2001-2002": {
        "top": ["SAC", "LAL","DAL", "SAS", "NJN", "DET"],
        "bottom": ["CHI","DEN" , "GSW", "MEM", "HOU", "CLE"]
    },
    "2002-2003": {
        "top": ["MIN", "SAC","DAL", "SAS", "DET", "LAL"],
        "bottom": ["MIA","TOR" , "CLE", "DEN", "LAC", "MEM"]
    },
    "2003-2004": {
        "top": ["IND", "MIN","LAL", "SAS", "SAC", "DET"],
        "bottom": ["ORL","CHI" , "WAS", "LAC", "ATL", "PHO"]
    },
    "2004-2005": {
        "top": ["MIA", "PHO","SAS", "DAL", "DET", "SEA"],
        "bottom": ["CHA","ATL" , "UTH", "NOH", "POR", "MIL"]
    },
    "2005-2006": {
        "top": ["DET", "SAS", "DAL", "PHO", "MIA", "CLE"],
        "bottom": ["POR","NYK" , "CHA", "ATL", "TOR", "MIN"]
    },
    "2006-2007": {
        "top": ["DAL", "PHO","SAS", "DET", "HOU", "UTH"],
        "bottom": ["MEM","BOS" , "MIL", "ATL", "SEA", "POR"]
    },
    "2007-2008": {
        "top": ["BOS", "DET","LAL", "NOH", "SAS", "HOU"],
        "bottom": ["MEM","MIA" , "SEA", "MIN", "NYK", "LAC"]
    },
    "2008-2009": {
        "top": ["CLE", "LAL","BOS", "ORL", "DEN", "POR"],
        "bottom": ["SAC","WAS" , "LAC", "OKC", "MIN", "MEM"]
    },
    "2009-2010": {
        "top": ["CLE", "ORL","LAL", "DAL", "PHO", "ATL"],
        "bottom": ["NJN","MIN", "SAC", "WAS", "GSW", "PHI"]
    },
    "2010-2011": {
        "top": ["CHI", "SAS","MIA", "DAL", "LAL", "BOS"],
        "bottom": ["MIN","CLE" , "TOR", "WAS" , "SAC", "NJN"]
    },
    "2011-2012": {
        "top": ["CHI", "SAS", "OKC", "MIA", "IND", "LAL"],
        "bottom": ["CHA", "WAS", "NOH", "CLE", "SAC", "NJN"]
    },
    "2012-2013": {
        "top": ["MIA", "OKC", "SAS", "DEN", "LAC", "MEM"],
        "bottom": ["CHA", "ORL", "CLE", "PHO", "NOH", "SAC"]
    },
    "2013-2014": {
        "top": ["SAS", "LAC", "OKC", "IND", "HOU", "MIA"],
        "bottom": ["MIL", "PHI", "ORL", "UTH", "BOS", "LAL"]
    },
    "2014-2015": {
        "top": ["GSW", "ATL", "HOU", "LAC","MEM", "SAS"],
        "bottom": ["MIN", "NYK", "PHI", "LAL", "ORL", "SAC"]
    },
    "2015-2016": {
        "top": ["GSW", "SAS", "CLE", "TOR", "OKC", "LAC"],
        "bottom": ["PHI", "LAL", "BRK", "PHO", "MIN", "NOP"]
    },
    "2016-2017": {
        "top": ["GSW", "SAS", "HOU", "BOS", "CLE", "LAC"],
        "bottom": ["BRK", "PHO", "LAL", "PHI", "ORL", "NYK"]
    },
    "2017-2018": {
        "top": ["HOU", "TOR", "GSW", "BOS", "PHI", "CLE"],
        "bottom": ["PHO", "MEM", "DAL", "ATL", "ORL", "SAC"]
    },
    "2018-2019": {
        "top": ["MIL", "TOR", "GSW", "DEN", "HOU", "POR"],
        "bottom": ["NYK", "PHO", "CLE", "CHI", "ATL", "WAS"]
    },
    "2019-2020": {
        "top": ["MIL", "TOR", "LAL", "LAC", "BOS", "DEN"],
        "bottom": ["GSW", "MIN", "CLE", "DET", "ATL", "NYK"]
    },
    "2020-2021": {
        "top": ["UTH", "PHO", "PHI", "BRK", "DEN", "LAC"],
        "bottom": ["HOU", "DET", "ORL", "OKC", "CLE", "MIN"]
    },
    "2021-2022": {
        "top": ["PHO", "MEM", "GSW", "MIA", "DAL", "BOS"],
        "bottom": ["HOU", "ORL", "DET", "OKC", "IND"]
    },
    "2022-2023": {
        "top": ["MIL", "BOS", "PHI", "DEN", "CLE", "MEM"],
        "bottom": ["DET", "SAS", "HOU", "CHA", "POR", "ORL"]
    }
}


def categorize_performance(row): #function to find the top, average, and bottom teams for that respective year 
    season = row['Season']
    team = row['Tm']
    for performance, teams in team_performance.get(season, {}).items():
        if team in teams:
            return performance
    return 'Average' 

def categorize_performance80(row): #function to find the top, average, and bottom teams for that respective year 
    season = row['Season']
    team = row['Tm']
    for performance, teams in team_performance2.get(season, {}).items():
        if team in teams:
            return performance
    return 'Average' 

bench_players2['Team Performance'] = bench_players2.apply(categorize_performance, axis=1)
bench_players2['Team Performance (20)'] = bench_players2.apply(categorize_performance80, axis=1)

bench_players2.to_csv("combined/99-23NBA_per_100_poss.csv")
