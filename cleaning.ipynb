# %%
import pandas as pd
import numpy as np  
import os

# %%
testdf = pd.read_csv("data/99-00NBA.csv")
testdf.drop(columns=['Rk', 'Player-additional'], errors='ignore', inplace=True)


def process_duplicates(df):
    duplicate_players = df[df.duplicated('Player', keep=False)]
    tot_df = duplicate_players[duplicate_players['Tm'] == 'TOT']
    filtered_duplicates = duplicate_players[~duplicate_players['Player'].isin(tot_df['Player'])]
    unique_non_tot = filtered_duplicates.drop_duplicates('Player', keep=False)
    final_df = pd.concat([df[~df['Player'].isin(duplicate_players['Player'])], tot_df, unique_non_tot]).reset_index(drop=True)
    
    return final_df

# %%
base_path = "data"

season_data_frames = []
for year in range(1999, 2023):
    #getting the directory of each file 
    season_file_name = f"{str(year)[2:]}-{str(year+1)[2:]}nba.csv"
    season_path = os.path.join(base_path, season_file_name)
    
    if os.path.isfile(season_path):
        season_data = pd.read_csv(season_path)
        season_data.drop(columns=['Rk', 'Player-additional'], errors='ignore', inplace=True)
        season_data['Season'] = f"{year}-{year+1}" 
        
        season_data = process_duplicates(season_data) # if a team was on multiple teams, they will be dropped, 
        
        season_data_frames.append(season_data)
    else:
        print(f"File not found for season: {year}-{year+1}")
combined_df = pd.concat(season_data_frames, ignore_index=True)
# Out:
#                       Player    Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  \
# 0        Shareef Abdur-Rahim     SF   23  VAN  82  82  39.3  7.2  15.6  0.465
# 1             Cory Alexander     PG   26  DEN  29   2  11.3  1.0   3.4  0.286
# 2                 Ray Allen*     SG   24  MIL  82  82  37.4  7.8  17.2  0.455
# 3               Rafer Alston     PG   23  MIL  27   0  13.4  1.0   3.5  0.284
# 4               John Amaechi      C   29  ORL  80  53  21.1  3.8   8.8  0.437
# ...                      ...    ...  ...  ...  ..  ..   ...  ...   ...    ...
# 11514  Juan Toscano-Anderson     SF   29  TOT  52   9  13.5  1.2   2.8  0.448
# 11515      Jarred Vanderbilt     PF   23  TOT  78  65  24.1  3.2   5.8  0.548
# 11516            T.J. Warren  PF-SF   29  TOT  42   0  16.4  3.1   6.4  0.489
# 11517      Russell Westbrook     PG   34  TOT  73  24  29.1  5.9  13.6  0.436
# 11518          James Wiseman      C   21  TOT  45  22  19.3  4.2   7.5  0.558
#
#        ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS     Season
# 0      ...  2.7  7.4  10.1  3.3  1.1  1.1  3.0  3.0  20.3  1999-2000
# 1      ...  0.3  1.2   1.4  2.0  0.8  0.1  1.0  1.3   2.8  1999-2000
# 2      ...  1.0  3.4   4.4  3.8  1.3  0.2  2.2  2.3  22.1  1999-2000
# 3      ...  0.2  0.7   0.9  2.6  0.4  0.0  1.1  1.1   2.2  1999-2000
# 4      ...  0.8  2.6   3.3  1.2  0.4  0.5  1.7  2.0  10.5  1999-2000
# ...    ...  ...  ...   ...  ...  ...  ...  ...  ...   ...        ...
# 11514  ...  0.5  1.8   2.4  1.3  0.3  0.2  0.7  1.5   3.0  2022-2023
# 11515  ...  2.2  5.3   7.5  2.4  1.1  0.3  1.2  2.4   7.9  2022-2023
# 11516  ...  0.6  2.3   2.9  1.0  0.5  0.3  0.5  1.5   7.5  2022-2023
# 11517  ...  1.2  4.6   5.8  7.5  1.0  0.5  3.5  2.2  15.9  2022-2023
# 11518  ...  1.6  4.3   5.9  0.7  0.2  0.6  1.1  2.4  10.0  2022-2023
#
# [11519 rows x 30 columns]
